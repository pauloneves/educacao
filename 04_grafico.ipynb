# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
df = pd.read_feather('dados/final.feather')
df = df.iloc[::-1, :45]
df['rotulo'] = df['rank'].str() + df.rotulo.str.split('/').str.get(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-61f0a6b20abd> in <module>
#       1 df = pd.read_feather('dados/final.feather')
#       2 df = df.iloc[::-1, :45]
# ----> 3 df['rotulo'] = df['rank'].str() + df.rotulo.str.split('/').str.get(0)
#
# ~\.conda\envs\edu\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\.conda\envs\edu\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
# ...

# %%
plt.rcParams["figure.figsize"] = (10,15)
plt.plot('mediana', 'rotulo', data=df, marker='d', linestyle='', alpha=.9)
plt.box(False)
plt.grid(False, axis='y')
